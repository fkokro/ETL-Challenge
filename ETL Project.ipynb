# %% [markdown]
# # ETL: Extract, Transform, Load Project

# %% [markdown]
# A major requirement for data scientist is to have the ability to extract multiple types of data from multiple soures, transform;
# meaning clean and structure the data into a desired form, then load the data into a database for future use. This project demonstrates the ETL process.

# %% [markdown]
# ### Webscraping nj.gov website for all New Jersey cities and ZIP Codes

# %%
# %matplotlib inline

# %%
#Import Relevant Libraries
from bs4 import BeautifulSoup as BS
import requests
import pandas as pd
import os 
import json
import psycopg2
from config import password
from config import user
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import inspect
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine

# %% [markdown]
# #### I. First source employees webscraping to collect all New Jersey Zip codes and Cities from Official State of New Jersey website

# %%
#URL of page to be scarped
url = "https://nj.gov/nj/gov/direct/njzips.html"    #Official Site of the State of New Jersey--Zip Codes
#retrieve page with request module
response = requests.get(url)
#Create a Beautiful Soup object
soup_njzips = BS(response.text, 'html.parser')
#Find all td tags in soup variable
tds = soup_njzips.find_all('td')

# %%
#Split tds list into 2 separate list 
ZIP_Codes = []
Post_Office = []
count = 0

for td in tds:
    
    if count == 2:
        count = 0
    else:
        if count == 0:
            ZIP_Codes.append(td.text)
            count += 1
        elif count == 1:
            Post_Office.append(td.text)
            count +=1

# %%
#Transforms our two liist into a single database
Jersey_cizips = pd.DataFrame({"Cities" : Post_Office,
                              "Zipcode": ZIP_Codes})

# %%
#Changing data types
Jersey_cizips['Zipcode'] = Jersey_cizips['Zipcode'].astype(str).str.zfill(5)
Jersey_cizips['Cities'] = Jersey_cizips['Cities'].astype(str)
Jersey_cizips.astype(str).dtypes
# Out:
# Cities     object
# Zipcode    object
# dtype: object

# %%
#Cleaning Data
Jersey_cizips_df =Jersey_cizips.drop(0)
zips = Jersey_cizips_df.drop_duplicates().reset_index().drop(columns=['index'])

# %%
# Save as a csv
path = ".\Output_Data"
zips.to_csv(os.path.join(path, 'zips.csv'))

# %%
# Connecct to postgres database
str_eng= f"postgresql://{user}:{password}@localhost:5432/New Jersey Data"
#print(str_eng)
engine = create_engine(str_eng)

# %%
#Export Table to Postgres Database
zips.to_sql(name='Zips', con=engine, if_exists='append', index=False)

# %% [markdown]
# #### ii. CSV file uploads

# %%
#Reading Census Buearu Economic Data into notebook
highest_paid = pd.read_csv('Resources/Highest Paid.csv')
Median_Household_Income = pd.read_csv('Resources/Median Household Income.csv')
Wage_Gender_Common_Jobs = pd.read_csv('Resources/Wage by Gender in Common Jobs.csv')
Wage_Distribution = pd.read_csv('Resources/Wage Distribution.csv')

# %% [markdown]
# ##### A. CSV Source One

# %%
#Explore data

# %%
highest_paid.head()
# Out:
#   ID Detailed Occupation                                Detailed Occupation  \
# 0                 291240                                           Surgeons
# 1                 113131                    Training & development managers
# 2                 291060                              Physicians & surgeons
# 3                 413031  Securities, commodities, & financial services ...
# 4                 291060                              Physicians & surgeons
#
#    ID Year  Year  ID Workforce Status  Workforce Status  Total Population  \
# 0     2018  2018                 True              True              2442
# 1     2015  2015                 True              True              1449
# 2     2017  2017                 True              True             27972
# 3     2018  2018                 True              True             13990
# 4     2016  2016                 True              True             26217
#
#    Total Population MOE Appx   Average Wage  Average Wage Appx MOE  \
# 0                1212.900062  346181.811220          126078.753693
# 1                 934.402396  252478.138026          156355.777010
# 2                4092.911705  242150.003325           27156.869530
# 3                2899.215398  238809.692781           45880.602148
# 4                3962.966655  237672.012435           29676.008581
#
#    ygopop RCA  Record Count  \
# 0    1.601845            28
# 1    0.777204            14
# 2    1.050649           314
# 3    2.166502           155
# 4    1.025195           288
#
#                             Slug Detailed Occupation   Geography ID Geography  \
# 0                                           surgeons  New Jersey    04000US34
# 1                      training-development-managers  New Jersey    04000US34
# 2                                physicians-surgeons  New Jersey    04000US34
# 3  securities-commodities-financial-services-sale...  New Jersey    04000US34
# 4                                physicians-surgeons  New Jersey    04000US34
#
#   Slug Geography
# 0     new-jersey
# 1     new-jersey
# 2     new-jersey
# 3     new-jersey
# 4     new-jersey

# %%
highest_paid.count()
# Out:
# ID Detailed Occupation       2062
# Detailed Occupation          2062
# ID Year                      2062
# Year                         2062
# ID Workforce Status          2062
# Workforce Status             2062
# Total Population             2062
# Total Population MOE Appx    2062
# Average Wage                 2062
# Average Wage Appx MOE        2062
# ygopop RCA                   2062
# Record Count                 2062
# Slug Detailed Occupation     2062
# Geography                    2062
# ID Geography                 2062
# Slug Geography               2062
# dtype: int64

# %%
highest_paid['Detailed Occupation'].value_counts()
# Out:
# Firstline supervisors of police & detectives                                               5
# Medical transcriptionists                                                                  5
# Word processors & typists                                                                  5
# Industrial & refractory machinery mechanics                                                5
# Customer service representatives                                                           5
#                                                                                           ..
# Nuclear medicine technologists and medical dosimetrists                                    1
# Other assemblers and fabricators                                                           1
# Nursing assistants                                                                         1
# Healthcare social workers                                                                  1
# Cutting, punching, and press machine setters, operators, and tenders, metal and plastic    1
# Name: Detailed Occupation, Length: 564, dtype: int64

# %%
highest_paid_df = highest_paid.sort_values(['Average Wage'], ascending=False).head(10)

# %%
highest_paid_df['Detailed Occupation'].value_counts()
# Out:
# Physicians & surgeons                                         3
# Training & development managers                               1
# Securities, commodities, & financial services sales agents    1
# Chief executives & legislators                                1
# Podiatrists                                                   1
# Other financial specialists                                   1
# Physicians                                                    1
# Surgeons                                                      1
# Name: Detailed Occupation, dtype: int64

# %%
highest_paid_df['ID Year']==2018
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# 8    False
# 9     True
# Name: ID Year, dtype: bool

# %%
highest_paid_slim = highest_paid_df.loc[highest_paid_df['ID Year']==2018]

# %%
highest_paid_slim = highest_paid_slim[['Detailed Occupation','Year','Average Wage','Average Wage Appx MOE','Record Count','Geography']]

# %%
highest_paid_slim = highest_paid_slim.reset_index()

# %%
highest_paid_slim = highest_paid_slim.drop(columns=['index'])

# %%
# Save as a csv
path = ".\Output_Data"
highest_paid_slim.to_csv(os.path.join(path, 'Highest Paying Jobs in NJ.csv'))

# %%
#Export Table to Postgres Database
highest_paid_slim.to_sql(name='Highest_Paying', con=engine, if_exists='append', index=False)

# %% [markdown]
# ##### B. CSV Source Two

# %%
#Clean median household data
Median_Household_Income.head()
# Out:
#    ID Year  Year  Household Income by Race  Household Income by Race Moe  \
# 0     2018  2018                     81740                         687.0
# 1     2018  2018                     78478                         729.0
# 2     2018  2018                     67844                         637.0
# 3     2018  2018                     61937                          94.0
# 4     2018  2018                     60905                         315.0
#
#                                Geography  ID Geography  \
# 0                             New Jersey     04000US34
# 1  New York-Newark-Jersey City, NY-NJ-PA  31000US35620
# 2                               New York     04000US36
# 3                          United States       01000US
# 4                           Pennsylvania     04000US42
#
#                                       Slug Geography
# 0                                         new-jersey
# 1  new-york-northern-new-jersey-long-island-ny-nj...
# 2                                           new-york
# 3                                      united-states
# 4                                       pennsylvania

# %%
#Edit data frame to contain relevant information
Median_Household_Income_Race = Median_Household_Income[['Year','Household Income by Race','Geography']].copy()
Median_Household_Income_Race.head(7)
# Out:
#    Year  Household Income by Race                                    Geography
# 0  2018                     81740                                   New Jersey
# 1  2018                     78478        New York-Newark-Jersey City, NY-NJ-PA
# 2  2018                     67844                                     New York
# 3  2018                     61937                                United States
# 4  2018                     60905                                 Pennsylvania
# 5  2018                     70747  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 6  2018                     64805                                     Delaware

# %%
# Save as a csv
path = ".\Output_Data"
Median_Household_Income_Race.to_csv(os.path.join(path, 'Median_Household_Income_Race.csv'))

# %%
#Export Table to Postgres Database
Median_Household_Income_Race.to_sql(name='Median_Household_Income_Race', con=engine, if_exists='append', index=False)

# %% [markdown]
# #### C.CSV Source Three

# %%
#Visualize data set
Wage_Gender_Common_Jobs.head()
# Out:
#    ID Gender  Gender  ID Year  Year  ID Employment Time Status  \
# 0          1    Male     2018  2018                          1
# 1          2  Female     2018  2018                          1
# 2          2  Female     2018  2018                          1
# 3          2  Female     2018  2018                          1
# 4          2  Female     2018  2018                          1
#
#   Employment Time Status ID Detailed Occupation  \
# 0              Full-time                 533030
# 1              Full-time                 533030
# 2              Full-time                 412031
# 3              Full-time                 1191XX
# 4              Full-time                 252020
#
#                     Detailed Occupation   Average Wage  Average Wage Appx MOE  \
# 0  Driver/sales workers & truck drivers   53894.578303            4662.225598
# 1  Driver/sales workers & truck drivers   47931.976408           21800.029358
# 2                   Retail salespersons   43984.466022            8839.108611
# 3                        Other managers  104982.016869            9984.577737
# 4   Elementary & middle school teachers   63685.354714            2539.277005
#
#    Total Population  Total Population MOE Appx  Record Count   Geography  \
# 0             79173                6829.999193           639  New Jersey
# 1              4154                1581.435393            31  New Jersey
# 2             23044                3714.724912           207  New Jersey
# 3             41971                4999.691939           449  New Jersey
# 4             91017                7310.451260           993  New Jersey
#
#   ID Geography Slug Geography
# 0    04000US34     new-jersey
# 1    04000US34     new-jersey
# 2    04000US34     new-jersey
# 3    04000US34     new-jersey
# 4    04000US34     new-jersey

# %%
Wage_Gender_Common_Jobs['Detailed Occupation'].value_counts()
# Out:
# Registered nurses                       10
# Driver/sales workers & truck drivers    10
# Retail salespersons                     10
# Elementary & middle school teachers     10
# Other managers                           2
# Name: Detailed Occupation, dtype: int64

# %%
Wage_Gender_Common_Jobs_df = Wage_Gender_Common_Jobs[['Gender','Year','Detailed Occupation','Total Population','Record Count','Geography']]

# %%
#Seperate the dataframe into male/female
Wage_by_gender_common_job_female = Wage_Gender_Common_Jobs_df.loc[Wage_Gender_Common_Jobs_df['Gender']=='Female',:]
Wage_by_gender_common_job_male = Wage_Gender_Common_Jobs_df.loc[Wage_Gender_Common_Jobs_df['Gender']=='Male',:]

# %%
Wage_by_gender_common_job_female.head()
# Out:
#    Gender  Year                   Detailed Occupation  Total Population  \
# 1  Female  2018  Driver/sales workers & truck drivers              4154
# 2  Female  2018                   Retail salespersons             23044
# 3  Female  2018                        Other managers             41971
# 4  Female  2018   Elementary & middle school teachers             91017
# 9  Female  2018                     Registered nurses             68999
#
#    Record Count   Geography
# 1            31  New Jersey
# 2           207  New Jersey
# 3           449  New Jersey
# 4           993  New Jersey
# 9           723  New Jersey

# %%
Wage_by_gender_common_job_male.head()
# Out:
#   Gender  Year                   Detailed Occupation  Total Population  \
# 0   Male  2018  Driver/sales workers & truck drivers             79173
# 5   Male  2018                     Registered nurses              9366
# 6   Male  2018                   Retail salespersons             33038
# 7   Male  2018                        Other managers             77553
# 8   Male  2018   Elementary & middle school teachers             26390
#
#    Record Count   Geography
# 0           639  New Jersey
# 5            91  New Jersey
# 6           311  New Jersey
# 7           793  New Jersey
# 8           272  New Jersey

# %%
# Save as a csv
path = ".\Output_Data"
Wage_by_gender_common_job_female.to_csv(os.path.join(path, 'Wage_by_gender_common_job_female.csv'))

# %%
# Save as a csv
path = ".\Output_Data"
Wage_by_gender_common_job_male.to_csv(os.path.join(path, 'Wage_by_gender_common_job_male.csv'))

# %%
#Export Table to Postgres Database
Wage_by_gender_common_job_female.to_sql(name='Wage_by_gender_common_job_female', con=engine, if_exists='append', index=False)

# %%
#Export Table to Postgres Database
Wage_by_gender_common_job_male.to_sql(name='Wage_by_gender_common_job_male', con=engine, if_exists='append', index=False)

# %% [markdown]
# #### D.CSV Source Four

# %%
#Clean wage distribution
Wage_Distribution.head()
# Out:
#    ID Wage Bin   Wage Bin  ID Year  Year  ID Workforce Status  \
# 0           11  $100-110k     2018  2018                 True
# 1           21     $200k+     2018  2018                 True
# 2           20  $190-200k     2018  2018                 True
# 3            2    $10-20k     2018  2018                 True
# 4           19  $180-190k     2018  2018                 True
#
#    Workforce Status  Total Population  Total Population MOE Appx  \
# 0              True           3994488               48408.844657
# 1              True            206142               10878.265107
# 2              True             13784                2877.859766
# 3              True          18713295               99337.336833
# 4              True             22945                3709.064473
#
#    Record Count      Geography ID Geography Slug Geography     share
# 0         40446  United States      01000US  united-states  0.026718
# 1          2311     New Jersey    04000US34     new-jersey  0.047635
# 2           148     New Jersey    04000US34     new-jersey  0.003185
# 3        168669  United States      01000US  united-states  0.125167
# 4           262     New Jersey    04000US34     new-jersey  0.005302

# %%
Wage_Distribution = Wage_Distribution[['Wage Bin','Year','Total Population','Record Count','Geography']]

# %%
Wage_Distribution.head()
# Out:
#     Wage Bin  Year  Total Population  Record Count      Geography
# 0  $100-110k  2018           3994488         40446  United States
# 1     $200k+  2018            206142          2311     New Jersey
# 2  $190-200k  2018             13784           148     New Jersey
# 3    $10-20k  2018          18713295        168669  United States
# 4  $180-190k  2018             22945           262     New Jersey

# %%
# Save as a csv
path = ".\Output_Data"
Wage_Distribution.to_csv(os.path.join(path, 'Wage_Distribution.csv'))

# %%
#Export Table to Postgres Database
Wage_by_gender_common_job_female.to_sql(name='Wage_by_gender_common_job_female', con=engine, if_exists='append', index=False)

# %% [markdown]
# #### iii. Load

# %%
print(engine.table_names())
# Out:
# ['wage_distribution', 'highest_paying', 'zips', 'median_household_income_race', 'wage_by_gender_common_job_female', 'wage_by_gender_common_job_male', 'Wage_by_gender_common_job_female', 'Wage_by_gender_common_job_male', 'Zips', 'Median_Household_Income_Race']

# %%
#Read sql table into pandas datafram
df1 = pd.read_sql("SELECT * FROM zips", con=engine)
df1.head()
# Out:
#    id     cities  zip_codes
# 0   0    Absecon       8201
# 1   1   Adelphia       7710
# 2   2    Allaire       7727
# 3   3  Allamuchy       7820
# 4   4  Allendale       7401

# %%
#Read sql table into pandas datafram
df2 = pd.read_sql("SELECT * FROM highest_paying", con=engine)
df2.head()
# Out:
#    id                                detailed_occupation  year   average_wage  \
# 0   0                                           Surgeons  2018  346181.811220
# 1   1  Securities, commodities, & financial services ...  2018  238809.692781
# 2   2                     Chief executives & legislators  2018  220187.561079
# 3   3                        Other financial specialists  2018  220077.199871
# 4   4                                        Podiatrists  2018  217798.366215
#
#    average_wage_appx_moe  record_count   geography
# 0          126078.753693            28  New Jersey
# 1           45880.602148           155  New Jersey
# 2           20749.672598           500  New Jersey
# 3          128114.746803            18  New Jersey
# 4          164558.500711            11  New Jersey

# %%
#Read sql table into pandas datafram
df3 = pd.read_sql("SELECT * FROM Wage_by_gender_common_job_male", con=engine)
df3.head()
# Out:
#    id gender  year                   detailed_occupation  total_population  \
# 0   0   Male  2018  Driver/sales workers & truck drivers             79173
# 1   5   Male  2018                     Registered nurses              9366
# 2   6   Male  2018                   Retail salespersons             33038
# 3   7   Male  2018                        Other managers             77553
# 4   8   Male  2018   Elementary & middle school teachers             26390
#
#    record_count   geography
# 0           639  New Jersey
# 1            91  New Jersey
# 2           311  New Jersey
# 3           793  New Jersey
# 4           272  New Jersey

# %%
#Read sql table into pandas datafram
df4 = pd.read_sql("SELECT * FROM Wage_by_gender_common_job_female", con=engine)
df4.head()
# Out:
#    id  gender  year                   detailed_occupation  total_population  \
# 0   1  Female  2018  Driver/sales workers & truck drivers              4154
# 1   2  Female  2018                   Retail salespersons             23044
# 2   3  Female  2018                        Other managers             41971
# 3   4  Female  2018   Elementary & middle school teachers             91017
# 4   9  Female  2018                     Registered nurses             68999
#
#    record_count   geography
# 0            31  New Jersey
# 1           207  New Jersey
# 2           449  New Jersey
# 3           993  New Jersey
# 4           723  New Jersey
